# %% [markdown]
# In this project I will be analysing the amount of young professonals using the public transport to commute to work. For this I will be analysing the data of 4 different variables:
#
# Age: which will be between 20 and 40
# Distance from workplace
# Amount of means of trasnport: one two or more than 2
# Houshold average salary:

# %% [markdown]
# One of the project requirements is to create these numbers using thenumpy.random package

# %% [markdown]
# To create 100 values between two numbers:
# https://pythonguides.com/python-numpy-random/

# %%
import matplotlib.pyplot as plt
import numpy as np
random_ages = np.random.randint(low=18, high=41, size=100)

# %%
print (random_ages)
# Out:
# [30 37 27 37 18 35 25 23 31 28 24 25 37 35 33 36 30 34 23 36 24 35 27 19
#  30 19 30 24 26 39 21 33 39 33 29 33 39 22 27 19 26 23 26 34 24 30 21 36
#  22 19 34 19 32 28 34 29 28 26 32 24 33 23 34 30 21 22 32 22 19 27 33 28
#  24 32 37 37 33 30 22 34 32 26 39 35 24 31 28 26 20 35 37 31 35 28 26 18
#  18 33 22 29]

# %%
plt.hist(random_ages)
plt.show()

# %%
random_salary = np.random.randint(low=40000, high=100000, size=100)
plt.hist(random_salary)
plt.show()

# %% [markdown]
# For distance I decided to use the normal random generator with a mean of distribution starting at 4Km, the reason for that is that empployees who live in a 4Km ratio would prefer to walk or cycle to work.
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.normal.html#

# %%
distance_wrk = np.random.normal (4, 1, 100)
plt.hist(distance_wrk)
plt.show()
